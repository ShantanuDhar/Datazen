# %%
company_data=sectors = {
    'PVTB': [{'name': 'HDFC Bank', 'code': 'HDFCBANK'}, 
             {'name': 'ICICI Bank', 'code': 'ICICIBANK'}, 
             {'name': 'Kotak Bank', 'code': 'KOTAKBANK'}, 
             {'name': 'Axis Bank', 'code': 'AXISBANK'}, 
             {'name': 'IndusInd Bank', 'code': 'INDUSINDBK'}],
    
    'IT': [{'name': 'Infosys', 'code': 'INFY'}, 
           {'name': 'TCS', 'code': 'TCS'}, 
           {'name': 'Wipro', 'code': 'WIPRO'}, 
           {'name': 'Tech Mahindra', 'code': 'TECHM'}, 
           {'name': 'HCL Tech', 'code': 'HCLTECH'}],
    
    'Telecom': [{'name': 'Bharti Airtel', 'code': 'BHARTIARTL'}, 
                {'name': 'Reliance', 'code': 'RELIANCE'}, 
                {'name': 'Vodafone Idea', 'code': 'IDEA'}, 
                {'name': 'MTNL', 'code': 'MTNL'}, 
                {'name': 'TTML', 'code': 'TTML'}],
    
    'Cement': [{'name': 'UltraTech Cement', 'code': 'ULTRACEMCO'}, 
               {'name': 'ACC', 'code': 'ACC'}, 
               {'name': 'Shree Cement', 'code': 'SHREECEM'}, 
               {'name': 'Ambuja Cement', 'code': 'AMBUJACEM'}, 
               {'name': 'Ramco Cement', 'code': 'RAMCOCEM'}],
    
    'Pharma': [{'name': 'Sun Pharma', 'code': 'SUNPHARMA'}, 
               {'name': 'Cipla', 'code': 'CIPLA'}, 
               {'name': 'Dr. Reddy\'s', 'code': 'DRREDDY'}, 
               {'name': 'Aurobindo Pharma', 'code': 'AUROPHARMA'}, 
               {'name': 'Biocon', 'code': 'BIOCON'}],
    
    'Infra': [{'name': 'L&T', 'code': 'LT'}, 
              {'name': 'BEML', 'code': 'BEML'}, 
              {'name': 'GMR Infra', 'code': 'GMRINFRA'}, 
              {'name': 'IRB Infra', 'code': 'IRB'}, 
              {'name': 'DLF', 'code': 'DLF'}],
    
    'NBFC': [{'name': 'Bajaj Finance', 'code': 'BAJFINANCE'}, 
             {'name': 'Muthoot Finance', 'code': 'MUTHOOTFIN'}, 
             {'name': 'LIC Housing Finance', 'code': 'LICHSGFIN'}, 
             {'name': 'Cholamandalam Finance', 'code': 'CHOLAFIN'}, 
             {'name': 'HDFC AMC', 'code': 'HDFCAMC'}],
    
    'FMCG': [{'name': 'Hindustan Unilever', 'code': 'HINDUNILVR'}, 
             {'name': 'ITC', 'code': 'ITC'}, 
             {'name': 'Nestle India', 'code': 'NESTLEIND'}, 
             {'name': 'Britannia', 'code': 'BRITANNIA'}, 
             {'name': 'Dabur', 'code': 'DABUR'}],
    
    'Others': [{'name': 'Apple', 'code': 'AAPL'}, 
               {'name': 'Amazon', 'code': 'AMZN'}, 
               {'name': 'Google', 'code': 'GOOGL'}, 
               {'name': 'Microsoft', 'code': 'MSFT'}, 
               {'name': 'Tesla', 'code': 'TSLA'}],
    
    'Metal': [{'name': 'Tata Steel', 'code': 'TATASTEEL'}, 
              {'name': 'Hindalco', 'code': 'HINDALCO'}, 
              {'name': 'JSW Steel', 'code': 'JSWSTEEL'}, 
              {'name': 'Vedanta', 'code': 'VEDL'}, 
              {'name': 'SAIL', 'code': 'SAIL'}],
    
    'PSUB': [{'name': 'PNB', 'code': 'PNB'}, 
             {'name': 'SBI', 'code': 'SBIN'}, 
             {'name': 'Bank of Baroda', 'code': 'BANKBARODA'}, 
             {'name': 'Canara Bank', 'code': 'CANBK'}, 
             {'name': 'Bank of India', 'code': 'BANKINDIA'}],
    
    'Power': [{'name': 'NTPC', 'code': 'NTPC'}, 
              {'name': 'Power Grid', 'code': 'POWERGRID'}, 
              {'name': 'Tata Power', 'code': 'TATAPOWER'}, 
              {'name': 'Adani Power', 'code': 'ADANIPOWER'}, 
              {'name': 'NHPC', 'code': 'NHPC'}],
    
    'Cap_Goods': [{'name': 'L&T', 'code': 'LT'}, 
                  {'name': 'Siemens', 'code': 'SIEMENS'}, 
                  {'name': 'ABB', 'code': 'ABB'}, 
                  {'name': 'BHEL', 'code': 'BHEL'}, 
                  {'name': 'Cummins India', 'code': 'CUMMINSIND'}],
    
    'Auto': [{'name': 'Maruti', 'code': 'MARUTI'}, 
             {'name': 'Tata Motors', 'code': 'TATAMOTORS'}, 
             {'name': 'Bajaj Auto', 'code': 'BAJAJ-AUTO'}, 
             {'name': 'Eicher Motors', 'code': 'EICHERMOT'}, 
             {'name': 'TVS Motor', 'code': 'TVSMOTOR'}],
    
    'Oil': [{'name': 'ONGC', 'code': 'ONGC'}, 
            {'name': 'BPCL', 'code': 'BPCL'}, 
            {'name': 'Hindustan Petroleum', 'code': 'HINDPETRO'}, 
            {'name': 'Reliance', 'code': 'RELIANCE'}, 
            {'name': 'IOC', 'code': 'IOC'}]
}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_financial_data(ticker, metric):
        
    # Create session and set headers
    session = requests.Session()
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5',
    }
    
    # Get company page
    url = f'https://www.screener.in/company/{ticker}/'
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables
        tables = soup.find_all('table', {'class': 'data-table'})
        
        if not tables:
            print("No data found")
            return None
            
        # Dictionary to store DataFrames
        dfs = {}
        
        # Process each table
        for table in tables:
            section = table.find_previous(['h2', 'h3'])
            if section:
                section_name = section.text.strip()
                df = pd.read_html(str(table))[0]
                
                # Clean up the DataFrame
                df = df.set_index(df.columns[0])
                df.index.name = 'Metric'
                
                # Store in dictionary
                dfs[section_name] = df
        
        # Return based on metric parameter
        if metric.lower() == 'pl':
            return dfs.get('Profit & Loss')
        elif metric.lower() == 'bs':
            return dfs.get('Balance Sheet')
        elif metric.lower() == 'q':
            return dfs.get('Quarterly Results')
        elif metric.lower() == 'r':
            return dfs.get('Ratios')
        elif metric.lower() == 'all':
            # Combine all DataFrames
            combined_df = pd.concat(dfs.values(), keys=dfs.keys(), axis=0)
            combined_df.index.names = ['Section', 'Metric']
            return combined_df
        else:
            print("Invalid metric specified")
            return None
            
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")


def get_financial_json(ticker):
    
    # Get just the quarterly results
    quarterly_df = get_financial_data(ticker, 'q')

    # Get just the profit and loss statement
    pl_df = get_financial_data(ticker, 'pl')

    bs_df=pl_df = get_financial_data(ticker, 'bs')
    
    f_df=pl_df = get_financial_data(ticker, 'r')
    
    return {
        'quarterly': quarterly_df.to_json(),
        'profit_loss': pl_df.to_json(),
        'balance_sheet': bs_df.to_json(),
        'ratio': f_df.to_json()
    }

# %%
# import http.client
# import json
# import os
# import pandas as pd
# import requests
# import dotenv

# # Load environment variables (ensure HUGGINGFACE_API_KEY is defined)
# dotenv.load_dotenv()
# huggingface_api_key = os.getenv("HUGGINGFACE_API_KEY")

# # HuggingFace model configuration for sentiment analysis
# API_URL = "https://api-inference.huggingface.co/models/ProsusAI/finbert"
# hf_headers = {"Authorization": f"Bearer {huggingface_api_key}"}

# def query(payload):
#     """
#     Send a request to the HuggingFace API with payload.
#     """
#     response = requests.post(API_URL, headers=hf_headers, json=payload)
#     return response.json()

# def get_highest_score_label(output):
#     """
#     Given HuggingFace output (a list with score dictionaries),
#     return the label corresponding to the highest score.
#     """
#     scores = output[0]
#     highest_score_dict = max(scores, key=lambda x: x['score'])
#     return highest_score_dict['label']

# def get_news_json(ticker):
#     """
#     Request news JSON from the livemint API and extract recent news.
#     Returns the extracted news list.
#     """
#     conn = http.client.HTTPSConnection("livemint-api.p.rapidapi.com")
#     headers = {
#         'x-rapidapi-key': "1e4f93d9f4msha2fc20ba862816cp172850jsn4981f6564d9b",
#         'x-rapidapi-host': "livemint-api.p.rapidapi.com"
#     }
#     conn.request("GET", f"/stock?name={ticker}", headers=headers)
#     res = conn.getresponse()
#     data = res.read()
#     decoded_data = data.decode("utf-8")
    
#     try:
#         json_data = json.loads(decoded_data)
        
#         def extract_all_news(data, key="recentNews"):
#             """Recursively search for 'recentNews' key in JSON."""
#             if isinstance(data, dict):
#                 if key in data:
#                     return data[key]
#                 for value in data.values():
#                     result = extract_all_news(value, key)
#                     if result:
#                         return result
#             elif isinstance(data, list):
#                 for item in data:
#                     result = extract_all_news(item, key)
#                     if result:
#                         return result
#             return None

#         # Extract news list and return it
#         all_news = extract_all_news(json_data, "recentNews")
#         return all_news

#     except json.JSONDecodeError as e:
#         print("Error decoding JSON:", e)
#         return None

# def get_news_df(ticker):
#     """
#     Create a pandas DataFrame from the news JSON data and perform sentiment analysis.
#     """
#     all_news = get_news_json(ticker)
#     if not all_news:
#         print("No news data available.")
#         return pd.DataFrame()
    
#     # Create a DataFrame from news list
#     df = pd.DataFrame(all_news)
    
#     # Ensure consistent columns (if any column is missing, create it with None)
#     columns = ['id', 'headline', 'intro', 'byline', 'date']
#     for col in columns:
#         if col not in df.columns:
#             df[col] = None
#     df = df[columns]
    
#     # Convert date to datetime type
#     df['date'] = pd.to_datetime(df['date'], errors='coerce')
    
#     # Define a helper to analyze sentiment based on text (using headline; modify if needed)
#     def analyze_sentiment(text):
#         try:
#             # Query the HuggingFace model
#             result = query({'inputs': text})
#             sentiment = get_highest_score_label(result)
#             return sentiment
#         except Exception as e:
#             # In case of any error, default to 'neutral'
#             return "neutral"
    
#     # Apply sentiment analysis to the 'headline' field; fallback to an empty string if missing
#     df['sentiment'] = df['headline'].apply(lambda x: analyze_sentiment(x) if x else analyze_sentiment(''))
    
#     return df

# # Usage example:
# if __name__ == "__main__":
#     try:
#         news_dataframe = get_news_df('HDFCBANK')
#         print(news_dataframe)
#     except Exception as e:
#         print("Error creating DataFrame:", e)

import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time

def fetch_google_stock_news(company_name, num_results=10):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5',
        'Connection': 'keep-alive',
    }
    
    # Improved search query with more financial news sources
    search_query = (f"{company_name} stock news "
                   "site:finance.yahoo.com OR "
                   "site:moneycontrol.com OR "
                   "site:livemint.com OR "
                   "site:economictimes.indiatimes.com OR "
                   "site:reuters.com OR "
                   "site:bloomberg.com")
    
    url = f"https://www.google.com/search?q={search_query}&tbm=nws&num={num_results}"
    
    try:
        # Add delay to avoid rate limiting
        time.sleep(2)
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        news_items = soup.find_all('div', {'class': ['SoaBEf', 'WlydOe']})
        
        news_data = []
        
        for item in news_items:
            try:
                # Extract title and link
                title_elem = item.find('div', class_=['n0jPhd', 'mCBkyc'])
                link_elem = item.find('a')
                source_elem = item.find('div', class_=['MgUUmf', 'NUnG9d'])
                date_elem = item.find('div', class_=['OSrXXb', 'ZE0LJd'])
                
                if all([title_elem, link_elem, source_elem, date_elem]):
                    title = title_elem.text.strip()
                    link = link_elem['href']
                    source = source_elem.text.strip()
                    date = date_elem.text.strip()
                    
                    # Extract snippet if available
                    snippet_elem = item.find('div', class_=['VwiC3b', 'yXK7lf'])
                    snippet = snippet_elem.text.strip() if snippet_elem else ""
                    
                    news_entry = {
                        'title': title,
                        'source': source,
                        'url': link,
                        'published': date,
                        'snippet': snippet
                    }
                    news_data.append(news_entry)
            
            except AttributeError:
                continue
        
        df = pd.DataFrame(news_data)
        # Remove duplicates based on title
        df = df.drop_duplicates(subset=['title'])
        return df
    
    except Exception as e:
        print(f"Error fetching news: {e}")
        return pd.DataFrame()

# if __name__ == "__main__":
#     company_name = "HDFCBANK"
#     news_df = fetch_google_stock_news(company_name)
    
#     if not news_df.empty:
#         print("\nLatest News Headlines:")
#         pd.set_option('display.max_colwidth', None)
#         print(news_df[['title', 'source', 'published', 'snippet']])
        
#         # Save to CSV with timestamp
#         timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#         filename = f"stock_news_{company_name}_{timestamp}.csv"
#         news_df.to_csv(filename, index=False, encoding='utf-8')
#         print(f"\nNews data saved to {filename}")
#     else:
#         print("No news found for this company.")

# %%
from neo4j import GraphDatabase
import pandas as pd
import time

uri = "neo4j+s://9a89da2e.databases.neo4j.io"  
user = "neo4j"                   # Your Neo4j username.
password = "6KaR1gdJgJpZDJBrpvGU4G3TpRzunffbYcCU3-v8Aeg"      # Your Neo4j password.

# Initialize Neo4j driver
driver = GraphDatabase.driver(uri, auth=(user, password))

# Function to insert company node
def create_company(tx, name, ticker, sector):
    tx.run("""
        MERGE (c:Company {ticker: $ticker})
        SET c.name = $name, c.sector = $sector
    """, name=name, ticker=ticker, sector=sector)

# Function to insert news article node
def create_news_article(tx, title, link, publisher, detailed_time, content, sentiment):
    tx.run("""
        CREATE (n:NewsArticle {title: $title, link: $link, publisher: $publisher, detailed_time: $detailed_time, content: $content, sentiment: $sentiment})
    """, title=title, link=link, publisher=publisher, detailed_time=detailed_time, content=content, sentiment=sentiment)

# Function to insert sector node
def create_sector(tx, name, description):
    tx.run("""
        MERGE (s:Sector {name: $name})
        SET s.description = $description
    """, name=name, description=description)

# Function to insert quarterly report node
def create_quarterly_report(tx, quarterly, profit_loss, balance_sheet, ratio):
    tx.run("""
        CREATE (q:QuarterlyReport {quarterly: $quarterly, profit_loss: $profit_loss, balance_sheet: $balance_sheet, ratio: $ratio})
    """, quarterly=quarterly, profit_loss=profit_loss, balance_sheet=balance_sheet, ratio=ratio)

# Functions to create specific relationships
def create_belongs_to(tx, company_ticker, sector_name):
    tx.run("""
        MATCH (c:Company {ticker: $company_ticker})
        MATCH (s:Sector {name: $sector_name})
        MERGE (c)-[:BELONGS_TO]->(s)
    """, company_ticker=company_ticker, sector_name=sector_name)

def create_mentions(tx, news_title, company_ticker):
    tx.run("""
        MATCH (n:NewsArticle {title: $news_title})
        MATCH (c:Company {ticker: $company_ticker})
        MERGE (n)-[:MENTIONS]->(c)
    """, news_title=news_title, company_ticker=company_ticker)

def create_reports_on(tx, company_ticker, quarterly):
    tx.run("""
        MATCH (c:Company {ticker: $company_ticker})
        MATCH (q:QuarterlyReport {quarterly: $quarterly})
        MERGE (q)-[:REPORTS_ON]->(c)
    """, company_ticker=company_ticker, quarterly=quarterly)

# Function to fetch data with retry logic
def fetch_data_with_retry(symbol, retries=3, delay=5):
    for attempt in range(retries):
        try:
            news_data = get_news_df(symbol)
            financial_data = get_financial_json(symbol[:-3])
            return news_data, financial_data
        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            if attempt < retries - 1:
                print("Retrying...")
                time.sleep(delay)
            else:
                print("Max retries reached. Skipping.")
                return None, None

# Insert data into Neo4j
def insert_data():
    with driver.session() as session:
        for sector, companies in company_data.items():
            # Insert sector
            session.write_transaction(create_sector, sector, f"{sector} sector")

            for company in companies:
                name = company['name']
                ticker = company['code']

                # Insert company node
                session.write_transaction(create_company, name, ticker, sector)

                # Fetch news and financial data with retry
                news_data, financial_data = fetch_data_with_retry(ticker)
                if news_data is None or financial_data is None:
                    continue

                quarterly_report_csv = financial_data['quarterly']
                profit_loss_json = financial_data['profit_loss']
                balance_sheet_json = financial_data['balance_sheet']
                ratio_json = financial_data['ratio']

                # Insert news articles
                for _, row in news_data.iterrows():
                    session.write_transaction(create_news_article, row['headline'], row['link'], row['publisher'], row['detailed_time'], row['content'], row['sentiment'])

                # Insert quarterly report
                session.write_transaction(create_quarterly_report, quarterly_report_csv, profit_loss_json, balance_sheet_json, ratio_json)

                # Create relationships
                session.write_transaction(create_belongs_to, ticker, sector)
                
                for _, row in news_data.iterrows():
                    session.write_transaction(create_mentions, row['headline'], ticker)

                session.write_transaction(create_reports_on, ticker, quarterly_report_csv)

# Run the data insertion function
insert_data()

# Close the Neo4j driver
driver.close()

# %%
from neo4j import GraphDatabase
import pandas as pd
import time

uri = "neo4j+s://9a89da2e.databases.neo4j.io"  
user = "neo4j"  
password = "6KaR1gdJgJpZDJBrpvGU4G3TpRzunffbYcCU3-v8Aeg"  

# Initialize Neo4j driver
driver = GraphDatabase.driver(uri, auth=(user, password))

# Function to insert company node
def create_company(tx, name, ticker, sector):
    tx.run("""
        MERGE (c:Company {ticker: $ticker})
        SET c.name = $name, c.sector = $sector
    """, name=name, ticker=ticker, sector=sector)

# Function to insert news article node (Updated structure)
def create_news_article(tx, news_id, headline, intro, byline, date, sentiment):
    tx.run("""
        MERGE (n:NewsArticle {id: $news_id})
        SET n.headline = $headline,
            n.intro = $intro,
            n.byline = $byline,
            n.date = $date,
            n.sentiment = $sentiment
    """, news_id=news_id, headline=headline, intro=intro, byline=byline, date=date, sentiment=sentiment)

# Function to insert sector node
def create_sector(tx, name, description):
    tx.run("""
        MERGE (s:Sector {name: $name})
        SET s.description = $description
    """, name=name, description=description)

# Function to insert quarterly report node
def create_quarterly_report(tx, quarterly, profit_loss, balance_sheet, ratio):
    tx.run("""
        MERGE (q:QuarterlyReport {quarterly: $quarterly})
        SET q.profit_loss = $profit_loss,
            q.balance_sheet = $balance_sheet,
            q.ratio = $ratio
    """, quarterly=quarterly, profit_loss=profit_loss, balance_sheet=balance_sheet, ratio=ratio)

# Functions to create relationships
def create_belongs_to(tx, company_ticker, sector_name):
    tx.run("""
        MATCH (c:Company {ticker: $company_ticker})
        MATCH (s:Sector {name: $sector_name})
        MERGE (c)-[:BELONGS_TO]->(s)
    """, company_ticker=company_ticker, sector_name=sector_name)

def create_mentions(tx, news_id, company_ticker):
    tx.run("""
        MATCH (n:NewsArticle {id: $news_id})
        MATCH (c:Company {ticker: $company_ticker})
        MERGE (n)-[:MENTIONS]->(c)
    """, news_id=news_id, company_ticker=company_ticker)

def create_reports_on(tx, company_ticker, quarterly):
    tx.run("""
        MATCH (c:Company {ticker: $company_ticker})
        MATCH (q:QuarterlyReport {quarterly: $quarterly})
        MERGE (q)-[:REPORTS_ON]->(c)
    """, company_ticker=company_ticker, quarterly=quarterly)

# Function to fetch data with retry logic
def fetch_data_with_retry(symbol, retries=3, delay=5):
    for attempt in range(retries):
        try:
            news_data = fetch_google_stock_news(symbol)
            financial_data = get_financial_json(symbol[:-3])
            return news_data, financial_data
        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            if attempt < retries - 1:
                print("Retrying...")
                time.sleep(delay)
            else:
                print("Max retries reached. Skipping.")
                return None, None

# Insert data into Neo4j
def insert_data():
    with driver.session() as session:
        for sector, companies in company_data.items():
            # Insert sector
            session.write_transaction(create_sector, sector, f"{sector} sector")

            for company in companies:
                name = company['name']
                ticker = company['code']

                # Insert company node
                session.write_transaction(create_company, name, ticker, sector)

                # Fetch news and financial data with retry
                news_data, financial_data = fetch_data_with_retry(ticker)
                if news_data is None or financial_data is None:
                    continue

                quarterly_report_csv = financial_data['quarterly']
                profit_loss_json = financial_data['profit_loss']
                balance_sheet_json = financial_data['balance_sheet']
                ratio_json = financial_data['ratio']

                # Insert news articles
                for _, row in news_data.iterrows():
                    session.write_transaction(create_news_article, row['id'], row['headline'], row['intro'], row['byline'], row['date'], row['sentiment'])

                # Insert quarterly report
                session.write_transaction(create_quarterly_report, quarterly_report_csv, profit_loss_json, balance_sheet_json, ratio_json)

                # Create relationships
                session.write_transaction(create_belongs_to, ticker, sector)
                
                for _, row in news_data.iterrows():
                    session.write_transaction(create_mentions, row['id'], ticker)

                session.write_transaction(create_reports_on, ticker, quarterly_report_csv)

# Run the data insertion function
insert_data()

# Close the Neo4j driver
driver.close()
# Out:
# /tmp/ipykernel_515025/2434528195.py:89: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_sector, sector, f"{sector} sector")
# /tmp/ipykernel_515025/2434528195.py:96: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_company, name, ticker, sector)
# Error fetching data: 404 Client Error: Not Found for url: https://www.screener.in/company/HDFCB/
# Error fetching data: 404 Client Error: Not Found for url: https://www.screener.in/company/HDFCB/
# Error fetching data: 404 Client Error: Not Found for url: https://www.screener.in/company/HDFCB/
# Error fetching data: 404 Client Error: Not Found for url: https://www.screener.in/company/HDFCB/
# Error fetching data for HDFCBANK: 'NoneType' object has no attribute 'to_json'
# Retrying...
# Error fetching data: 404 Client Error: Not Found for url: https://www.screener.in/company/HDFCB/
# ...

# %%
from neo4j import GraphDatabase
import pandas as pd
import time

uri = "neo4j+s://9a89da2e.databases.neo4j.io"  
user = "neo4j"  
password = "6KaR1gdJgJpZDJBrpvGU4G3TpRzunffbYcCU3-v8Aeg"  

# Initialize Neo4j driver
driver = GraphDatabase.driver(uri, auth=(user, password))

# Function to insert company node
def create_company(tx, name, ticker, sector):
    tx.run("""
        MERGE (c:Company {ticker: $ticker})
        SET c.name = $name, c.sector = $sector
    """, name=name, ticker=ticker, sector=sector)

# Function to insert news article node (Updated structure)
def create_news_article(tx, title, source, url, published):
    tx.run("""
        MERGE (n:NewsArticle {title: $title})
        SET n.source = $source,
            n.url = $url,
            n.published = $published
    """, title=title, source=source, url=url, published=published)

# Function to insert sector node
def create_sector(tx, name, description):
    tx.run("""
        MERGE (s:Sector {name: $name})
        SET s.description = $description
    """, name=name, description=description)

# Function to insert quarterly report node
def create_quarterly_report(tx, quarterly, profit_loss, balance_sheet, ratio):
    tx.run("""
        MERGE (q:QuarterlyReport {quarterly: $quarterly})
        SET q.profit_loss = $profit_loss,
            q.balance_sheet = $balance_sheet,
            q.ratio = $ratio
    """, quarterly=quarterly, profit_loss=profit_loss, balance_sheet=balance_sheet, ratio=ratio)

# Functions to create relationships
def create_belongs_to(tx, company_ticker, sector_name):
    tx.run("""
        MATCH (c:Company {ticker: $company_ticker})
        MATCH (s:Sector {name: $sector_name})
        MERGE (c)-[:BELONGS_TO]->(s)
    """, company_ticker=company_ticker, sector_name=sector_name)

def create_mentions(tx, news_title, company_ticker):
    tx.run("""
        MATCH (n:NewsArticle {title: $news_title})
        MATCH (c:Company {ticker: $company_ticker})
        MERGE (n)-[:MENTIONS]->(c)
    """, news_title=news_title, company_ticker=company_ticker)

def create_reports_on(tx, company_ticker, quarterly):
    tx.run("""
        MATCH (c:Company {ticker: $company_ticker})
        MATCH (q:QuarterlyReport {quarterly: $quarterly})
        MERGE (q)-[:REPORTS_ON]->(c)
    """, company_ticker=company_ticker, quarterly=quarterly)

# Function to fetch data with retry logic
def fetch_data_with_retry(symbol, retries=3, delay=5):
    for attempt in range(retries):
        try:
            news_data = fetch_google_stock_news(symbol)
            financial_data = get_financial_json(symbol)
            return news_data, financial_data
        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            if attempt < retries - 1:
                print("Retrying...")
                time.sleep(delay)
            else:
                print("Max retries reached. Skipping.")
                return None, None

# Insert data into Neo4j
def insert_data():
    with driver.session() as session:
        for sector, companies in company_data.items():
            # Insert sector
            session.write_transaction(create_sector, sector, f"{sector} sector")

            for company in companies:
                name = company['name']
                ticker = company['code']

                # Insert company node
                session.write_transaction(create_company, name, ticker, sector)

                # Fetch news and financial data with retry
                news_data, financial_data = fetch_data_with_retry(ticker)
                if news_data is None or financial_data is None:
                    continue

                quarterly_report_csv = financial_data['quarterly']
                profit_loss_json = financial_data['profit_loss']
                balance_sheet_json = financial_data['balance_sheet']
                ratio_json = financial_data['ratio']

                # Insert news articles
                for _, row in news_data.iterrows():
                    session.write_transaction(create_news_article, row['title'], row['source'], row['url'], row['published'])

                # Insert quarterly report
                session.write_transaction(create_quarterly_report, quarterly_report_csv, profit_loss_json, balance_sheet_json, ratio_json)

                # Create relationships
                session.write_transaction(create_belongs_to, ticker, sector)
                
                for _, row in news_data.iterrows():
                    session.write_transaction(create_mentions, row['title'], ticker)

                session.write_transaction(create_reports_on, ticker, quarterly_report_csv)

# Run the data insertion function
insert_data()

# Close the Neo4j driver
driver.close()
# Out:
# /tmp/ipykernel_515025/1578720477.py:87: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_sector, sector, f"{sector} sector")
# /tmp/ipykernel_515025/1578720477.py:94: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_company, name, ticker, sector)
# /tmp/ipykernel_515025/2393419799.py:39: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /tmp/ipykernel_515025/2393419799.py:39: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# ...
